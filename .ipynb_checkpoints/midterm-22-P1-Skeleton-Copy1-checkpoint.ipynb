# %%
from rl.dynamic_programming import V, S, A
from rl import dynamic_programming

# %%
from rl import markov_process, markov_decision_process

# %%
import operator
from typing import Mapping, Iterator, TypeVar, Tuple, Dict, Iterable

import numpy as np

from rl.distribution import Categorical, Choose
from rl.iterate import converged, iterate
from rl.markov_process import NonTerminal, State
from rl.markov_decision_process import (FiniteMarkovDecisionProcess,
                                        FiniteMarkovRewardProcess)
from rl.policy import FinitePolicy, FiniteDeterministicPolicy

# %%
from rl.midterm_2022.priority_q import  PriorityQueue
from rl.midterm_2022 import grid_maze

# %%
import importlib

# %%
from time import time

# %% [markdown]
# # Problem 1

# %% [markdown]
# In this problem we will implement the gaps-based value iteration algorithm mentioned in class.
#
# The gaps-based iteration algorithm proceeds as follows
#
# 1. Initialize the value function to zero for all states: $v[s] = 0\ \forall s \in \mathcal{N}$
# 2. Calculate the gaps for each state: $g[s] = |v[s] - \max_a \mathcal{R}(s,a) + \sum_{s'} \mathcal{P}(s,a,s') \cdot v(s')|$
# 3. While there is some gap that exceeds a threshold
#  - Select the state with the  largest gap: $s_{max} = \arg\max_{s \in \mathcal{N}} g[s]$
#  - Update the value function for $s_{max}$: $v[s_{max}] = \max_a \mathcal{R}(s_{max},a) + \sum_{s'}\mathcal{P}(s_{max},a,s') \cdot v(s')$
#  -  Update the gap for $s_{max}$: $g[s_{max}] = 0$
# 4. Return v

# %% [markdown]
# We will test your implementation on a grid maze MDP. We have defined this class in "grid_maze.py", you should  briefly familiarize yourself with that code. In particular pay attention to the difference in reward functions for the two classes "GridMazeMDP_Dense" and "GridMazeMDP_Sparse"

# %% [markdown]
# Here is how you can use the classes:

# %%
underlying_maze = grid_maze.Maze(10, 10)
maze_mdp = grid_maze.GridMazeMDP_Sparse(underlying_maze, 0, 0)

# %% [markdown]
# you can visualize the maze if you wish

# %%
print(maze_mdp)
# Out:
# --------------------
# |*  |         | |   |
# | +-+ +-+-+ + + + +-+
# |       |   |       |
# | +-+-+-+-+-+-+-+ +-+
# |             | | | |
# | +-+ + +-+ +-+ +-+ +
# |   | |   |         |
# | +-+-+ +-+-+-+-+ + +
# |   |     | |   | | |
# |-+ +-+-+-+ +-+ + + +
# |     |       | | | |
# | +-+ + +-+-+-+ +-+-+
# |   |   | | |     | |
# | + + + + + + +-+-+ +
# | | | |     |       |
# |-+ + + + +-+ +-+-+-+
# |   | | |           |
# | + +-+ +-+ + +-+-+-+
# | |   |   | |       |
# |-+-+-+-+-+-+-+-+-+-+

# %% [markdown]
# you can also visualize a policy on the mdp

# %%
v2_res = dynamic_programming.value_iteration_result(maze_mdp, 0.9)
print(maze_mdp.print_policy(v2_res[1]))
# Out:
# --------------------
# |* <|v < < < <|v|v <|
# | +-+ +-+-+ + + + +-+
# |^ < < <|> ^|^ < < <|
# | +-+-+-+-+-+-+-+ +-+
# |^ < < < < < <|v|^|v|
# | +-+ + +-+ +-+ +-+ +
# |^ <|^|^ <|^ < < < <|
# | +-+-+ +-+-+-+-+ + +
# |^ <|> ^ <|v|> v|^|^|
# |-+ +-+-+-+ +-+ + + +
# |> ^ <|v < < <|v|^|^|
# | +-+ + +-+-+-+ +-+-+
# |^ <|^ <|v|v|v < <|v|
# | + + + + + + +-+-+ +
# |^|^|^|^ < <|v < < <|
# |-+ + + + +-+ +-+-+-+
# |> ^|^|^|^ < < < < <|
# | + +-+ +-+ + +-+-+-+
# |^|^ <|^ <|^|^ < < <|
# |-+-+-+-+-+-+-+-+-+-+

# %% [markdown]
# You will need to make use of the PriorityQueue class in your implementation. A PriorityQueue is an ordered queue which supports the following operations
# 1. isEmpty(self): check if the queue is empty
# 2. contains(self, element): check if the queue contains an element
# 3. peek(self): peek at the highest priority element in the queue
# 4. pop(self): remove and return the highest priority element in the queue
# 5. insert(self, element, priority): insert an element into the queue with given priority
# 6. update(self, element, new_priority): update the priority of an element in the queue
# 7. delete(self, element): delete an element from the queue
#
# Below are some examples of using the queue

# %%
q: PriorityQueue = PriorityQueue()
print(q.isEmpty(), ':', "the queue is empty")
q.insert("a", 1)
print(q.isEmpty(), ':',  "the queue is not empty")
print(q.contains("a"), ':',  "the queue contains a")
print(q.contains("b"), ':',  "the queue does not contain a")
print(q.peek(), ':',  "a is the first element in the queue")
q.insert("b", 0)
print(q.contains("b"), ':',  "the queue now contains b")
print(q.peek(), ':',  "b is now at the front of the queue")
x = q.pop()
print(x, ':',  "we removed b from the queue")
print(q.isEmpty(), ':',  "the queue still nonempty")
print(q.contains("a"), ':',  "the queue still contains a")
print(q.contains("b"), ':',  "the queue does not contain b anymore")
print(q.peek(), ':',  "a is at the front of the queue")
q.insert("c", 5)
print(q.peek(), ':',  "a is still at the front of the queue")
q.update("a", 6)
print(q.peek(), ':',  "after updating a is no longer at the front of the queue")
# Out:
# True : the queue is empty
# False : the queue is not empty
# True : the queue contains a
# False : the queue does not contain a
# (1, 'a') : a is the first element in the queue
# True : the queue now contains b
# (0, 'b') : b is now at the front of the queue
# b : we removed b from the queue
# False : the queue still nonempty
# True : the queue still contains a
# False : the queue does not contain b anymore
# (1, 'a') : a is at the front of the queue
# (1, 'a') : a is still at the front of the queue
# (5, 'c') : after updating a is no longer at the front of the queue

# %% [markdown]
# ### Part 1

# %%
from collections import defaultdict
def invert_transition_map(mdp: markov_decision_process.FiniteMarkovDecisionProcess[S, A]) ->\
            Mapping[S, Iterable[S]]:
    '''
    YOUR CODE HERE
    Implement the invert_transition_map method
    '''
    inverted_mapping: Dict[S, Iterable[S]] = {}
    mdp_mapping: Mapping[S, Mapping[A, FiniteDistribution[Tuple[S, float]]]] = mdp.mapping
    
    for currState in mdp_mapping.keys():
        inverted_mapping[currState.state] = set()
    
    for currState in mdp_mapping.keys():
        action_map = mdp_mapping[currState]
        
        possibleNewStates: Set[S] = set()
            
        for dist_map in action_map.values():
            for new_state_and_reward, prob in dist_map:
                new_state = new_state_and_reward[0]
                if prob > 0 and (new_state in mdp_mapping.keys()):
                    inverted_mapping[new_state.state].add(currState.state)       
        
    #raise NotImplementedError
    '''END YOUR CODE'''
    return inverted_mapping

# %% [markdown]
# ### Part 2

# %%
def gaps_value_iteration(
    mdp: markov_decision_process.FiniteMarkovDecisionProcess[S, A],
    gamma: float, 
    gaps: PriorityQueue) -> Iterator[V[S]]:
    '''
    Calculate the value function (V*) of the given MDP by applying the
    update function repeatedly until the values converge.

    '''
    dependency_map = invert_transition_map(mdp)
    #print(dependency_map)
    v_0: V[S] = {s: 0.0 for s in mdp.non_terminal_states}
    #print(v_0)
        
    def update(v: V[S]) -> V[S]:
        #print(v)
        #print(mdp.mapping)
        maxStateGap: Tuple[S, float] = gaps.peek()
        #print(maxStateGap)
        #print(gaps)
        maxState: S = maxStateGap[1]
            
        maxState_action_map = mdp.mapping[NonTerminal(maxState)]
        
        def bestActionValue(state_action_map): 
            action_value_map: Dict[A, float] = {}
            max_val = float('-inf')
            for dist_map in state_action_map.values():
                #dist_map = state_action_map[action]

                reward: float = 0
                future_value: float = 0

                for stateReward, prob in dist_map:
                    reward += prob * stateReward[1]
                    if stateReward[0] in mdp.non_terminal_states:
                        future_value += gamma * prob * v[stateReward[0]]

                max_val = max(future_value + reward, max_val)
            
            return max_val
            #bestAction = max(action_value_map, key=action_value_map.get)
            #bestValue = action_value_map[bestAction]
            
            #return max(action_value_map.values())
            #return bestValue
        
        #print("Old value for: " + str(maxState) + " is: " + str(v[NonTerminal(maxState)]))
        v[NonTerminal(maxState)] = bestActionValue(maxState_action_map)
        #print("New value for: " + str(maxState) + " is: " + str(v[NonTerminal(maxState)]))
        gaps.update(maxState, 0)
        
        #print("MaxState: " + str(maxState))
        #print(dependency_map[maxState])
        
        for dependent_state in dependency_map[maxState]:
            dependent_state_best_val = bestActionValue(mdp.mapping[NonTerminal(dependent_state)])
            stateNewGap = abs(v[NonTerminal(dependent_state)] - dependent_state_best_val)
            gaps.update(dependent_state, -stateNewGap)

            
        '''
        YOUR CODE HERE
        perform a single update to v for the state with the largest gap
        update the gaps for any dependent states
        '''
        #raise NotImplementedError 
        '''END YOUR CODE'''
        return v

    
    return iterate(update, v_0)


def gaps_value_iteration_result(
    mdp: FiniteMarkovDecisionProcess[S, A],
    gamma: float
) -> Tuple[V[S], FiniteDeterministicPolicy[S, A]]:
    
    gaps = PriorityQueue()

    v: V[S] = {s: 0.0 for s in mdp.non_terminal_states}
    
    def bestActionValue(state_action_map): 
        action_value_map: Dict[A, float] = {}

        for action in state_action_map.keys():
            dist_map = state_action_map[action]

            reward: float = 0
            future_value: float = 0

            for stateReward, prob in dist_map:
                reward += prob * stateReward[1]
                if stateReward[0] in mdp.non_terminal_states:
                    future_value += gamma * prob * v[stateReward[0]]

                #future_value += gamma * prob * v[stateReward[0].state]

            action_value_map[action] = future_value + reward

        bestAction = max(action_value_map, key=action_value_map.get)
        bestValue = action_value_map[bestAction]

        return max(action_value_map.values())
        return bestValue
    
    for s in mdp.non_terminal_states:
        gaps.insert(s.state, -abs(bestActionValue(mdp.mapping[s])))
        
    #print(gaps)
    
    '''
    YOUR CODE HERE
    instantiate the value function and populate the gaps
    ''' 
    #raise NotImplementedError
    ''' END YOUR CODE ''' 
    
    def criterion(x,y):
        THRESHOLD = 1e-5
        return abs(gaps.peek()[0]) < THRESHOLD
        ''' END YOUR CODE ''' 
        
    opt_vf: V[S] = converged(
        gaps_value_iteration(mdp, gamma, gaps),
        done= criterion 
    )
        
    opt_policy: markov_decision_process.FiniteDeterministicPolicy[S, A] = dynamic_programming.greedy_policy_from_vf(
        mdp,
        opt_vf,
        gamma
    )

    return opt_vf, opt_policy

# %% [markdown]
# # Do not change the code below here, just run it

# %% [markdown]
# ## Calculating the VF for a maze with sparse rewards

# %%
underlying_maze = grid_maze.Maze(50, 50)
maze_mdp = grid_maze.GridMazeMDP_Sparse(underlying_maze, 0, 0)
#print(maze_mdp)

# %% [markdown]
# #### printing the runtime for the calculation

# %%
start = time()
v1_res = gaps_value_iteration_result(maze_mdp, 0.9)
print(time() - start)
# Out:
# 50.18228721618652

# %%
#print(v1_res)

# %%
start = time()
v2_res = dynamic_programming.value_iteration_result(maze_mdp, 0.9)
#print(v2_res)
print(time() - start)
# Out:
# 1.8609130382537842

# %% [markdown]
# #### confirming that the value functions are identical

# %%
assert v1_res[1] == v2_res[1]

# %% [markdown]
# ## Calculating the VF for a maze with dense rewards

# %%
maze_mdp = grid_maze.GridMazeMDP_Dense(underlying_maze, 0, 0)

# %% [markdown]
# #### printing the runtime for the calculation

# %%
start = time()
v1_res = gaps_value_iteration_result(maze_mdp, 1)
print(time() - start)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-271-79f64952d0e4> in <module>
#       1 start = time()
# ----> 2 v1_res = gaps_value_iteration_result(maze_mdp, 1)
#       3 print(time() - start)
#
# <ipython-input-258-179f04164fd9> in gaps_value_iteration_result(mdp, gamma)
#     123         ''' END YOUR CODE '''
#     124
# --> 125     opt_vf: V[S] = converged(
#     126         gaps_value_iteration(mdp, gamma, gaps),
#     127         done= criterion
#
# ~/Documents/GitHub/RL-book/rl/iterate.py in converged(values, done)
#      73     Will loop forever if the input iterator doesn't end *or* converge.
#      74     '''
# ---> 75     result = last(converge(values, done))
#      76
#      77     if result is None:
#
# ~/Documents/GitHub/RL-book/rl/iterate.py in last(values)
#      35     '''
#      36     try:
# ---> 37         *_, last_element = values
#      38         return last_element
#      39     except ValueError:
#
# ~/Documents/GitHub/RL-book/rl/iterate.py in converge(values, done)
#      56     yield a
#      57
# ---> 58     for b in values:
#      59         yield b
#      60         if done(a, b):
#
# ~/Documents/GitHub/RL-book/rl/iterate.py in iterate(step, start)
#      24     while True:
#      25         yield state
# ---> 26         state = step(state)
#      27
#      28
#
# <ipython-input-258-179f04164fd9> in update(v)
#      57             dependent_state_best_val = bestActionValue(mdp.mapping[NonTerminal(dependent_state)])
#      58             stateNewGap = abs(v[NonTerminal(dependent_state)] - dependent_state_best_val)
# ---> 59             gaps.update(dependent_state, -stateNewGap)
#      60
#      61
#
# ~/Documents/GitHub/RL-book/rl/midterm_2022/priority_q.py in update(self, element, new_priority)
#      36     def update(self, element, new_priority):
#      37         assert element in self.elements
# ---> 38         self.delete(element)
#      39         self.insert(element, new_priority)
#      40
#
# ~/Documents/GitHub/RL-book/rl/midterm_2022/priority_q.py in delete(self, element)
#      45         while next_element != element:
#      46             popped_off.append((next_priority, next_element))
# ---> 47             next_priority, next_element = heapq.heappop(self.queue)
#      48         self.elements.remove(element)
#      49         for priority, elem in popped_off:
#
# ~/Documents/GitHub/RL-book/rl/midterm_2022/grid_maze.py in __eq__(self, other)
#
# KeyboardInterrupt:

# %%
start = time()
v2_res = dynamic_programming.value_iteration_result(maze_mdp, 1)
print(time() - start)
# Out:
# 2.441632032394409

# %% [markdown]
# #### confirming that the value functions are identical

# %%
assert v1_res[1] == v2_res[1]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-247-77ed15a31885> in <module>
# ----> 1 assert v1_res[1] == v2_res[1]
#
# AssertionError:

# %%
print(v1_res[0])
# Out:
# {NonTerminal(state=GridState(x=0, y=1)): 0, NonTerminal(state=GridState(x=0, y=2)): 0.0, NonTerminal(state=GridState(x=0, y=3)): 0, NonTerminal(state=GridState(x=0, y=4)): 0.0, NonTerminal(state=GridState(x=0, y=5)): 0, NonTerminal(state=GridState(x=0, y=6)): 0, NonTerminal(state=GridState(x=0, y=7)): 0, NonTerminal(state=GridState(x=0, y=8)): 0.0, NonTerminal(state=GridState(x=0, y=9)): 0, NonTerminal(state=GridState(x=0, y=10)): 0.0, NonTerminal(state=GridState(x=0, y=11)): 0, NonTerminal(state=GridState(x=0, y=12)): 0, NonTerminal(state=GridState(x=0, y=13)): 0, NonTerminal(state=GridState(x=0, y=14)): 0.0, NonTerminal(state=GridState(x=0, y=15)): 0, NonTerminal(state=GridState(x=0, y=16)): 0.0, NonTerminal(state=GridState(x=0, y=17)): 0, NonTerminal(state=GridState(x=0, y=18)): 0, NonTerminal(state=GridState(x=0, y=19)): 0.0, NonTerminal(state=GridState(x=0, y=20)): 0, NonTerminal(state=GridState(x=0, y=21)): 0.0, NonTerminal(state=GridState(x=0, y=22)): 0, NonTerminal(state=GridState(x=0, y=23)): 0.0, NonTerminal(state=GridState(x=0, y=24)): 0, NonTerminal(state=GridState(x=0, y=25)): 0, NonTerminal(state=GridState(x=0, y=26)): 0, NonTerminal(state=GridState(x=0, y=27)): 0, NonTerminal(state=GridState(x=0, y=28)): 0, NonTerminal(state=GridState(x=0, y=29)): 0.0, NonTerminal(state=GridState(x=0, y=30)): 0, NonTerminal(state=GridState(x=0, y=31)): 0.0, NonTerminal(state=GridState(x=0, y=32)): 0, NonTerminal(state=GridState(x=0, y=33)): 0.0, NonTerminal(state=GridState(x=0, y=34)): 0, NonTerminal(state=GridState(x=0, y=35)): 0, NonTerminal(state=GridState(x=0, y=36)): 0.0, NonTerminal(state=GridState(x=0, y=37)): 0, NonTerminal(state=GridState(x=0, y=38)): 0, NonTerminal(state=GridState(x=0, y=39)): 0.0, NonTerminal(state=GridState(x=0, y=40)): 0, NonTerminal(state=GridState(x=0, y=41)): 0, NonTerminal(state=GridState(x=0, y=42)): 0.0, NonTerminal(state=GridState(x=0, y=43)): 0, NonTerminal(state=GridState(x=0, y=44)): 0.0, NonTerminal(state=GridState(x=0, y=45)): 0, NonTerminal(state=GridState(x=0, y=46)): 0.0, NonTerminal(state=GridState(x=0, y=47)): 0, NonTerminal(state=GridState(x=0, y=48)): 0.0, NonTerminal(state=GridState(x=0, y=49)): 0, NonTerminal(state=GridState(x=1, y=0)): 0, NonTerminal(state=GridState(x=1, y=1)): 0.0, NonTerminal(state=GridState(x=1, y=2)): 0, NonTerminal(state=GridState(x=1, y=3)): 0, NonTerminal(state=GridState(x=1, y=4)): 0.0, NonTerminal(state=GridState(x=1, y=5)): 0, NonTerminal(state=GridState(x=1, y=6)): 0.0, NonTerminal(state=GridState(x=1, y=7)): 0.0, NonTerminal(state=GridState(x=1, y=8)): 0, NonTerminal(state=GridState(x=1, y=9)): 0.0, NonTerminal(state=GridState(x=1, y=10)): 0, NonTerminal(state=GridState(x=1, y=11)): 0.0, NonTerminal(state=GridState(x=1, y=12)): 0.0, NonTerminal(state=GridState(x=1, y=13)): 0, NonTerminal(state=GridState(x=1, y=14)): 0.0, NonTerminal(state=GridState(x=1, y=15)): 0.0, NonTerminal(state=GridState(x=1, y=16)): 0, NonTerminal(state=GridState(x=1, y=17)): 0.0, NonTerminal(state=GridState(x=1, y=18)): 0.0, NonTerminal(state=GridState(x=1, y=19)): 0, NonTerminal(state=GridState(x=1, y=20)): 0.0, NonTerminal(state=GridState(x=1, y=21)): 0, NonTerminal(state=GridState(x=1, y=22)): 0.0, NonTerminal(state=GridState(x=1, y=23)): 0, NonTerminal(state=GridState(x=1, y=24)): 0, NonTerminal(state=GridState(x=1, y=25)): 0.0, NonTerminal(state=GridState(x=1, y=26)): 0.0, NonTerminal(state=GridState(x=1, y=27)): 0.0, NonTerminal(state=GridState(x=1, y=28)): 0.0, NonTerminal(state=GridState(x=1, y=29)): 0, NonTerminal(state=GridState(x=1, y=30)): 0.0, NonTerminal(state=GridState(x=1, y=31)): 0, NonTerminal(state=GridState(x=1, y=32)): 0.0, NonTerminal(state=GridState(x=1, y=33)): 0, NonTerminal(state=GridState(x=1, y=34)): 0, NonTerminal(state=GridState(x=1, y=35)): 0.0, NonTerminal(state=GridState(x=1, y=36)): 0, NonTerminal(state=GridState(x=1, y=37)): 0.0, NonTerminal(state=GridState(x=1, y=38)): 0.0, NonTerminal(state=GridState(x=1, y=39)): 0, NonTerminal(state=Grid ...

# %%
print(v2_res[0])
# Out:
# {NonTerminal(state=GridState(x=0, y=1)): -1.0, NonTerminal(state=GridState(x=0, y=2)): -2.0, NonTerminal(state=GridState(x=0, y=3)): -3.0, NonTerminal(state=GridState(x=0, y=4)): -4.0, NonTerminal(state=GridState(x=0, y=5)): -5.0, NonTerminal(state=GridState(x=0, y=6)): -8.0, NonTerminal(state=GridState(x=0, y=7)): -9.0, NonTerminal(state=GridState(x=0, y=8)): -10.0, NonTerminal(state=GridState(x=0, y=9)): -11.0, NonTerminal(state=GridState(x=0, y=10)): -12.0, NonTerminal(state=GridState(x=0, y=11)): -21.0, NonTerminal(state=GridState(x=0, y=12)): -20.0, NonTerminal(state=GridState(x=0, y=13)): -23.0, NonTerminal(state=GridState(x=0, y=14)): -22.0, NonTerminal(state=GridState(x=0, y=15)): -23.0, NonTerminal(state=GridState(x=0, y=16)): -24.0, NonTerminal(state=GridState(x=0, y=17)): -25.0, NonTerminal(state=GridState(x=0, y=18)): -26.0, NonTerminal(state=GridState(x=0, y=19)): -27.0, NonTerminal(state=GridState(x=0, y=20)): -28.0, NonTerminal(state=GridState(x=0, y=21)): -29.0, NonTerminal(state=GridState(x=0, y=22)): -30.0, NonTerminal(state=GridState(x=0, y=23)): -31.0, NonTerminal(state=GridState(x=0, y=24)): -32.0, NonTerminal(state=GridState(x=0, y=25)): -37.0, NonTerminal(state=GridState(x=0, y=26)): -38.0, NonTerminal(state=GridState(x=0, y=27)): -39.0, NonTerminal(state=GridState(x=0, y=28)): -40.0, NonTerminal(state=GridState(x=0, y=29)): -41.0, NonTerminal(state=GridState(x=0, y=30)): -42.0, NonTerminal(state=GridState(x=0, y=31)): -43.0, NonTerminal(state=GridState(x=0, y=32)): -46.0, NonTerminal(state=GridState(x=0, y=33)): -45.0, NonTerminal(state=GridState(x=0, y=34)): -46.0, NonTerminal(state=GridState(x=0, y=35)): -47.0, NonTerminal(state=GridState(x=0, y=36)): -48.0, NonTerminal(state=GridState(x=0, y=37)): -53.0, NonTerminal(state=GridState(x=0, y=38)): -52.0, NonTerminal(state=GridState(x=0, y=39)): -53.0, NonTerminal(state=GridState(x=0, y=40)): -54.0, NonTerminal(state=GridState(x=0, y=41)): -57.0, NonTerminal(state=GridState(x=0, y=42)): -56.0, NonTerminal(state=GridState(x=0, y=43)): -57.0, NonTerminal(state=GridState(x=0, y=44)): -58.0, NonTerminal(state=GridState(x=0, y=45)): -59.0, NonTerminal(state=GridState(x=0, y=46)): -60.0, NonTerminal(state=GridState(x=0, y=47)): -61.0, NonTerminal(state=GridState(x=0, y=48)): -62.0, NonTerminal(state=GridState(x=0, y=49)): -63.0, NonTerminal(state=GridState(x=1, y=0)): -1.0, NonTerminal(state=GridState(x=1, y=1)): -2.0, NonTerminal(state=GridState(x=1, y=2)): -3.0, NonTerminal(state=GridState(x=1, y=3)): -6.0, NonTerminal(state=GridState(x=1, y=4)): -5.0, NonTerminal(state=GridState(x=1, y=5)): -6.0, NonTerminal(state=GridState(x=1, y=6)): -7.0, NonTerminal(state=GridState(x=1, y=7)): -8.0, NonTerminal(state=GridState(x=1, y=8)): -9.0, NonTerminal(state=GridState(x=1, y=9)): -10.0, NonTerminal(state=GridState(x=1, y=10)): -17.0, NonTerminal(state=GridState(x=1, y=11)): -20.0, NonTerminal(state=GridState(x=1, y=12)): -19.0, NonTerminal(state=GridState(x=1, y=13)): -22.0, NonTerminal(state=GridState(x=1, y=14)): -21.0, NonTerminal(state=GridState(x=1, y=15)): -22.0, NonTerminal(state=GridState(x=1, y=16)): -23.0, NonTerminal(state=GridState(x=1, y=17)): -24.0, NonTerminal(state=GridState(x=1, y=18)): -25.0, NonTerminal(state=GridState(x=1, y=19)): -26.0, NonTerminal(state=GridState(x=1, y=20)): -27.0, NonTerminal(state=GridState(x=1, y=21)): -30.0, NonTerminal(state=GridState(x=1, y=22)): -31.0, NonTerminal(state=GridState(x=1, y=23)): -32.0, NonTerminal(state=GridState(x=1, y=24)): -37.0, NonTerminal(state=GridState(x=1, y=25)): -36.0, NonTerminal(state=GridState(x=1, y=26)): -37.0, NonTerminal(state=GridState(x=1, y=27)): -38.0, NonTerminal(state=GridState(x=1, y=28)): -39.0, NonTerminal(state=GridState(x=1, y=29)): -42.0, NonTerminal(state=GridState(x=1, y=30)): -41.0, NonTerminal(state=GridState(x=1, y=31)): -42.0, NonTerminal(state=GridState(x=1, y=32)): -43.0, NonTerminal(state=GridState(x=1, y=33)): -44.0, NonTerminal(state=GridState(x=1, y=34)): -47.0, No ...
